# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# %%
df=pd.read_csv('polovni automobili.csv')

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df['name'].sort_values()
# Out:
# 3378       Ambassador CLASSIC 1500 DSL AC
# 4712    Ambassador Classic 2000 DSZ AC PS
# 4974      Ambassador Grand 1500 DSZ BSIII
# 7896      Ambassador Grand 2000 DSZ PW CL
# 4011               Ashok Leyland Stile LE
#                       ...
# 6170       Volvo XC40 D4 Inscription BSIV
# 3251               Volvo XC40 D4 R-Design
# 145                Volvo XC40 D4 R-Design
# 7516       Volvo XC60 Inscription D5 BSIV
# 170         Volvo XC90 T8 Excellence BSIV
# Name: name, Length: 8128, dtype: object

# %%
df.shape
# Out:
# (8128, 13)

# %%
msno.matrix(df)
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.loc[df['year']>2019, ['name','year','km_driven','fuel','transmission']].head(20)
# Out:
#                                      name  year  km_driven    fuel  \
# 106   Ford Freestyle Titanium Petrol BSIV  2020       5000  Petrol
# 115                    Maruti Celerio VXI  2020      13000  Petrol
# 196    Hyundai Elite i20 Sportz Plus BSIV  2020       5000  Petrol
# 224             Hyundai Xcent 1.2 VTVT SX  2020      32000  Petrol
# 402           Maruti Eeco CNG 5 Seater AC  2020      35000     CNG
# 460                   Datsun RediGO 1.0 S  2020       2136  Petrol
# 487          Mahindra KUV 100 D75 K6 Plus  2020      44665  Diesel
# 583            Maruti Swift Dzire VXI 1.2  2020       1500  Petrol
# 749                   Maruti Alto K10 VXI  2020       6000  Petrol
# 920              Maruti Alto 800 VXI Plus  2020      15000  Petrol
# 1067             Kia Seltos HTX Plus AT D  2020       5000  Diesel
# 1397  Toyota Innova Crysta 2.4 G MT 8 STR  2020      20102  Diesel
# 1461                   Mahindra XUV500 W7  2020     120000  Diesel
# ...

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df['mileage'].isna().sum()
# Out:
# 221

# %%
df['fuel'].mode()
# Out:
# 0    Diesel
# Name: fuel, dtype: object

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
df.duplicated(keep=False).sum()
# Out:
# 1827

# %%
df.sort_values(by=['year'], ascending=False)
# Out:
#                                      name  year  selling_price  km_driven  \
# 6630              Tata Tiago 2019-2020 XZ  2020         500000      15000
# 7429                     Maruti Swift LXI  2020         445000       1000
# 1397  Toyota Innova Crysta 2.4 G MT 8 STR  2020        1560000      20102
# 5053                Maruti Ignis Zeta AMT  2020         600000       5000
# 460                   Datsun RediGO 1.0 S  2020         350000       2136
# ...                                   ...   ...            ...        ...
# 1432             Mahindra Jeep CL 500 MDI  1994         120000     100000
# 1474                        Maruti 800 AC  1994          45000      60000
# 4712    Ambassador Classic 2000 DSZ AC PS  1994          99000     100000
# 5322             Maruti Omni LPG STD BSIV  1991          55000     120000
# 316             Mahindra Willys CJ 3B 4X4  1983         300000      10000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# ...

# %%
#obrisati bhp i prebaciti u numericki zapis kolonu max_power
df['max_power']=df['max_power'].str.replace('bhp','')

# %%
df.loc[4933:4934, ['name', 'max_power']]
# Out:
#                                          name max_power
# 4933                          Maruti Omni CNG
# 4934  Maruti Vitara Brezza ZDi Plus Dual Tone     88.5

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC       74
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC   103.52
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC       78
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC       90
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC     88.2
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
df.sort_values(by=['km_driven'], ascending=False)
# Out:
#                                                name  year  selling_price  \
# 3486                           Hyundai i20 Asta 1.2  2007         550000
# 1810                         Mahindra XUV500 W6 2WD  2012         500000
# 3508                       Maruti Wagon R LXI Minor  2010         194000
# 3641                       Maruti Wagon R VXI BS IV  2011         229999
# 6673  Toyota Innova 2.5 EV Diesel PS 7 Seater BSIII  2011         350000
# ...                                             ...   ...            ...
# 2963                           Maruti Swift AMT VXI  2020         654000
# 7429                               Maruti Swift LXI  2020         445000
# 7589                               Maruti Swift LXI  2020         445000
# 6638                 Toyota Innova Crysta 2.4 ZX AT  2020        2300000
# 7913         Maruti Eeco 5 STR With AC Plus HTR CNG  2011         209000
#
#       km_driven    fuel seller_type transmission                 owner  \
# ...

# %%
df['km_driven'].max()
# Out:
# 2360457

# %%
df['km_driven'].min()
# Out:
# 1

# %%
df['year'].value_counts()
# Out:
# year
# 2017    1018
# 2016     859
# 2018     807
# 2015     776
# 2013     670
# 2012     651
# 2014     621
# 2011     592
# 2019     583
# 2010     394
# 2009     246
# 2008     214
# 2007     183
# 2006     124
# 2005      97
# 2020      74
# 2004      62
# 2003      49
# 2002      27
# 2000      22
# 1999      18
# 1997      11
# 2001      10
# 1998      10
# 1996       3
# 1994       3
# 1995       2
# 1983       1
# 1991       1
# Name: count, dtype: int64

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       7078
# Automatic    1050
# Name: count, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %%
df['seats'].value_counts()
# Out:
# seats
# 5.0     6254
# 7.0     1120
# 8.0      236
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: count, dtype: int64

# %%
df.head(20)
# Out:
#                                     name  year  selling_price  km_driven  \
# 0                 Maruti Swift Dzire VDI  2014         450000     145500
# 1           Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2               Honda City 2017-2020 EXi  2006         158000     140000
# 3              Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                 Maruti Swift VXI BSIII  2007         130000     120000
# 5          Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6           Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                     Maruti 800 DX BSII  2001          45000       5000
# 8                       Toyota Etios VXD  2011         350000      90000
# 9   Ford Figo Diesel Celebration Edition  2013         200000     169000
# 10       Renault Duster 110PS Diesel RxL  2014         500000      68000
# 11                         Maruti Zen LX  2005          92000     100000
# ...

# %%
df.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
df['mileage']=pd.to_numeric(df['mileage'].str.replace('kmpl','').str.replace('km/kg',''))

# %%
df['engine']=pd.to_numeric(df['engine'].str.replace('CC',''))

# %%
df.dropna(inplace=True)

# %%
df['max_power']=(pd.to_numeric(df['max_power'])).astype (str)

# %%
df['max_power']=pd.to_numeric(df['max_power'])

# %%
df[['car','model']]=df['name'].str.split(' ', n=1, expand=True)

# %%
df.drop(columns=['name'], inplace=True)

# %%
#najprodavaniji auto
df['car'].value_counts().idxmax()
# Out:
# 'Maruti'

# %%
df['transmission'].value_counts()
# Out:
# transmission
# Manual       6865
# Automatic    1041
# Name: count, dtype: int64

# %%
#koji proizvodjac ima najvise broj oglasa 
df['car'].value_counts()
# Out:
# car
# Maruti           2367
# Hyundai          1360
# Mahindra          758
# Tata              719
# Honda             466
# Toyota            452
# Ford              388
# Chevrolet         230
# Renault           228
# Volkswagen        185
# BMW               118
# Skoda             104
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               41
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Name: count, dtype: int64

# %%
df['car'].max()
# Out:
# 'Volvo'

# %%
df.loc[df['car']==df['car'].max()]
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 145   2018        3400000      22000  Diesel      Dealer    Automatic
# 170   2017       10000000      30000  Petrol  Individual    Automatic
# 374   2019        3800000      20000  Diesel  Individual    Automatic
# 388   2018        2475000       2000  Diesel      Dealer    Automatic
# 413   2019        3800000      20000  Diesel  Individual    Automatic
# ...    ...            ...        ...     ...         ...          ...
# 6977  2018        2475000       2000  Diesel      Dealer    Automatic
# 7516  2018        5500000      50000  Diesel  Individual    Automatic
# 7862  2019        3800000      20000  Diesel  Individual    Automatic
# 7876  2018        2475000       2000  Diesel      Dealer    Automatic
# 7930  2019        5500000      17000  Diesel  Individual    Automatic
#
#             owner  mileage  engine  max_power               torque  seats  \
# ...

# %%
df.isna().sum()
# Out:
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# car              0
# model            0
# dtype: int64

# %%
msno.matrix(df)
plt.show()

# %%
#df['mileage']=pd.to_numeric(df['mileage'].str.replace('kmpl','').str.replace('km/kg',''))
#df['torque']=pd.to_numeric(df['torque'].str.replace('Nm@','').str.replace('rpm','').str.replace('kgm','').str.replace('@',''))
#df[['torque', 'rpm']]=df['torque'].str.split('@', expand=True)

# %%
df.loc[df['max_power']==df['max_power'].max()]
# Out:
#      year  selling_price  km_driven    fuel seller_type transmission  \
# 170  2017       10000000      30000  Petrol  Individual    Automatic
#
#            owner  mileage  engine  max_power          torque  seats    car  \
# 170  First Owner     42.0  1969.0      400.0  640Nm@ 1740rpm    4.0  Volvo
#
#                        model
# 170  XC90 T8 Excellence BSIV

# %%
df.loc[df['max_power']==df['max_power'].min()]
# Out:
#       year  selling_price  km_driven fuel seller_type transmission  \
# 3466  2010         120000     170000  LPG  Individual       Manual
# 6007  2007          54000     144000  LPG  Individual       Manual
#
#              owner  mileage  engine  max_power         torque  seats     car  \
# 3466  Second Owner     10.9   796.0       32.8  57Nm@ 2500rpm    5.0  Maruti
# 6007  Second Owner     10.9   796.0       32.8  57Nm@ 2500rpm    5.0  Maruti
#
#                                    model
# 3466  Omni LPG CARGO BSIII W IMMOBILISER
# 6007  Omni LPG CARGO BSIII W IMMOBILISER

# %%
df['km_driven'].corr(df['selling_price'])
# Out:
# -0.22215847533483768

# %%
df['seats'].mean()
# Out:
# 5.4163926132051605

# %%
#ovde vidimo sto je veca kilometraza manja je cena i obratno
sns.scatterplot(x='km_driven', y='selling_price', data=df)
plt.show()

# %%
sns.lineplot(data=df, x='selling_price', y='km_driven')
plt.show()
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# rsd u e
df['selling_price']=df['selling_price'] / 117.3

# %%
sns.lineplot(data=df, x='selling_price', y='km_driven')
plt.show()
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=df, x='selling_price', y='km_driven')
plt.show()
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# opisati ovo u tekstu 
df.describe()
# Out:
#               year  selling_price     km_driven      mileage       engine  \
# count  7906.000000    7906.000000  7.906000e+03  7906.000000  7906.000000
# mean   2013.983936    5539.758916  6.918866e+04    19.419861  1458.708829
# std       3.863695    6935.914308  5.679230e+04     4.036263   503.893057
# min    1994.000000     255.745951  1.000000e+00     0.000000   624.000000
# 25%    2012.000000    2301.790281  3.500000e+04    16.780000  1197.000000
# 50%    2015.000000    3836.317136  6.000000e+04    19.300000  1248.000000
# 75%    2017.000000    5882.352941  9.542500e+04    22.320000  1582.000000
# max    2020.000000   85251.491901  2.360457e+06    42.000000  3604.000000
#
#          max_power        seats
# count  7906.000000  7906.000000
# mean     91.587374     5.416393
# std      35.747216     0.959208
# min      32.800000     2.000000
# 25%      68.050000     5.000000
# 50%      82.000000     5.000000
# 75%     102.000000     5.000000
# max     400.000000    14.000000

# %%
def split_torque(torque_str):
    if pd.isna(torque_str):
        return pd.NA, pd.NA
    
    parts = torque_str.split('@')
    value = parts[0].strip() if len(parts) > 0 else pd.NA
    rpm = parts[1].strip() if len(parts) > 1 else pd.NA

    return value, rpm


df[['Torque Value', 'Torque RPM']] = df['torque'].apply(lambda x: split_torque(x)).tolist()


df[['torque', 'Torque Value', 'Torque RPM']].head()
# Out:
#                      torque              Torque Value    Torque RPM
# 0            190Nm@ 2000rpm                     190Nm       2000rpm
# 1       250Nm@ 1500-2500rpm                     250Nm  1500-2500rpm
# 2     12.7@ 2,700(kgm@ rpm)                      12.7     2,700(kgm
# 3  22.4 kgm at 1750-2750rpm  22.4 kgm at 1750-2750rpm          <NA>
# 4     11.5@ 4,500(kgm@ rpm)                      11.5     4,500(kgm

# %%
df.drop(columns=['torque'], inplace=True)

# %%
df
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014    3836.317136     145500  Diesel  Individual       Manual
# 1     2014    3154.305200     120000  Diesel  Individual       Manual
# 2     2006    1346.973572     140000  Petrol  Individual       Manual
# 3     2010    1918.158568     127000  Diesel  Individual       Manual
# 4     2007    1108.269395     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013    2728.047741     110000  Petrol  Individual       Manual
# 8124  2007    1150.895141     119000  Diesel  Individual       Manual
# 8125  2009    3256.606991     120000  Diesel  Individual       Manual
# 8126  2013    2472.293265      25000  Diesel  Individual       Manual
# 8127  2013    2472.293265      25000  Diesel  Individual       Manual
#
#                      owner  mileage  engine  max_power  seats      car  \
# ...

# %%
df.isna().sum()
# Out:
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage            0
# engine             0
# max_power          0
# seats              0
# car                0
# model              0
# Torque Value       0
# Torque RPM       265
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# seats            0
# car              0
# model            0
# Torque Value     0
# Torque RPM       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7641 entries, 0 to 8127
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7641 non-null   int64
#  1   selling_price  7641 non-null   float64
#  2   km_driven      7641 non-null   int64
#  3   fuel           7641 non-null   object
#  4   seller_type    7641 non-null   object
#  5   transmission   7641 non-null   object
#  6   owner          7641 non-null   object
#  7   mileage        7641 non-null   float64
#  8   engine         7641 non-null   float64
#  9   max_power      7641 non-null   float64
#  10  seats          7641 non-null   float64
#  11  car            7641 non-null   object
#  12  model          7641 non-null   object
#  13  Torque Value   7641 non-null   object
#  14  Torque RPM     7641 non-null   object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 955.1+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7641 entries, 0 to 8127
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           7641 non-null   int64
#  1   selling_price  7641 non-null   float64
#  2   km_driven      7641 non-null   int64
#  3   fuel           7641 non-null   object
#  4   seller_type    7641 non-null   object
#  5   transmission   7641 non-null   object
#  6   owner          7641 non-null   object
#  7   mileage        7641 non-null   float64
#  8   engine         7641 non-null   float64
#  9   max_power      7641 non-null   float64
#  10  seats          7641 non-null   float64
#  11  car            7641 non-null   object
#  12  model          7641 non-null   object
#  13  Torque Value   7641 non-null   object
#  14  Torque RPM     7641 non-null   object
# dtypes: float64(5), int64(2), object(8)
# memory usage: 955.1+ KB

# %%
df.head(20)
# Out:
#     year  selling_price  km_driven    fuel seller_type transmission  \
# 0   2014    3836.317136     145500  Diesel  Individual       Manual
# 1   2014    3154.305200     120000  Diesel  Individual       Manual
# 2   2006    1346.973572     140000  Petrol  Individual       Manual
# 4   2007    1108.269395     120000  Petrol  Individual       Manual
# 5   2017    3751.065644      45000  Petrol  Individual       Manual
# 6   2007     818.414322     175000     LPG  Individual       Manual
# 7   2001     383.631714       5000  Petrol  Individual       Manual
# 8   2011    2983.802217      90000  Diesel  Individual       Manual
# 9   2013    1705.029838     169000  Diesel  Individual       Manual
# 10  2014    4262.574595      68000  Diesel  Individual       Manual
# 11  2005     784.313725     100000  Petrol  Individual       Manual
# 12  2009    2387.041773     140000  Diesel  Individual       Manual
# 14  2009    1534.526854      90000  Petrol  Individual       Manual
# ...

# %%
df.loc[1:4, 'year']
# Out:
# 1    2014
# 2    2006
# 4    2007
# Name: year, dtype: int64
